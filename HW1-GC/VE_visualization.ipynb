# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
names_list = ['Energy_load',	'Energy_distribution', 'Problem_Choice', 'Agent_choice','Resolutions', 'Oversights', 'Flights',	'Quickies',	'Prob_unsolved','Prob_shifts',	'Prob_active', 'Prob_latency','Dm_active', 'Dm_shifts', 'Energy_spent', 'Energy_excess', 'Choices_unsolved', 'Choices_active']

# %%
from gc import garbage
ve = pd. read_excel('garbage_can_v_41.xls', header = None, names = names_list)

#slice dataframe to get needed data
ve_data =  ve.loc[0:44,' ':'Flights' ]

# %%
g = sns.FacetGrid(ve_data, col = 'Energy_distribution', row = 'Problem_Choice')
g.map_dataframe(sns.lineplot, 'Agent_choice','Resolutions')

# %%
data_long = pd.melt(ve_data, ['Energy_distribution','Problem_Choice','Agent_choice'])
data_long
# Out:
#      Energy_distribution  Problem_Choice  Agent_choice     variable  value
# 0                      0               0             0  Resolutions    0.0
# 1                      0               0             1  Resolutions    0.3
# 2                      0               0             2  Resolutions    0.0
# 3                      0               0             3  Resolutions    0.0
# 4                      0               0             4  Resolutions    0.0
# ..                   ...             ...           ...          ...    ...
# 130                    2               2             0      Flights    0.0
# 131                    2               2             1      Flights    0.0
# 132                    2               2             2      Flights    0.0
# 133                    2               2             3      Flights    0.0
# 134                    2               2             4      Flights    0.0
#
# [135 rows x 5 columns]

# %%
g = sns.FacetGrid(data_long, col = 'Energy_distribution', row = 'Problem_Choice')
g.map_dataframe(sns.lineplot, x ='Agent_choice',y = 'value', hue = 'variable')
g.add_legend()

# %%
ve_data.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot()

# %%
ve_data
# Out:
#     Energy_distribution  Problem_Choice  Agent_choice  Resolutions  \
# 0                     0               0             0         0.00
# 1                     0               0             1         0.30
# 2                     0               0             2         0.00
# 3                     0               0             3         0.00
# 4                     0               0             4         0.00
# 5                     0               1             0         2.09
# 6                     0               1             1         2.81
# 7                     0               1             2         1.98
# 8                     0               1             3         2.31
# 9                     0               1             4         2.25
# 10                    0               2             0         0.00
# 11                    0               2             1         2.43
# 12                    0               2             2         5.40
# 13                    0               2             3         4.95
# 14                    0               2             4         4.38
# 15                    1               0             0         0.00
# 16                    1               0             1         0.51
# 17                    1               0             2         0.00
# 18                    1               0             3         0.00
# 19                    1               0             4         0.00
# 20                    1               1             0         1.39
# 21                    1               1             1         2.50
# 22                    1               1             2         1.68
# 23                    1               1             3         2.98
# 24                    1               1             4         2.10
# 25                    1               2             0         0.00
# 26                    1               2             1         2.61
# 27                    1               2             2         7.18
# 28                    1               2             3         1.77
# 29                    1               2             4         5.17
# 30                    2               0             0         0.00
# 31                    2               0             1         0.76
# 32                    2               0             2         0.00
# 33                    2               0             3         0.00
# 34                    2               0             4         0.00
# 35                    2               1             0         1.46
# 36                    2               1             1         1.70
# 37                    2               1             2         1.68
# 38                    2               1             3         2.17
# 39                    2               1             4         1.62
# 40                    2               2             0         0.00
# 41                    2               2             1         1.50
# 42                    2               2             2         5.36
# 43                    2               2             3         0.00
# 44                    2               2             4         4.21
#
#     Oversights  Flights
# 0         0.00     0.00
# 1         8.76     8.76
# 2         9.00     9.00
# 3         9.00     9.00
# 4         9.00     9.00
# 5         4.05     3.75
# 6         6.55     7.71
# 7         8.18     8.14
# 8         7.49     7.73
# 9         7.56     8.25
# 10        2.74     0.00
# 11        2.85     0.00
# 12        2.71     0.00
# 13        2.98     0.00
# 14        2.80     0.00
# 15        0.00     0.00
# 16        8.45     8.45
# 17        9.00     9.00
# 18        9.00     9.00
# 19        9.00     9.00
# 20        2.87     2.00
# 21        5.89     6.73
# 22        8.34     8.06
# 23        5.56     6.43
# 24        7.52     7.89
# 25        2.69     0.00
# 26        2.84     0.00
# 27        2.82     0.00
# 28        2.92     0.00
# 29        2.74     0.00
# 30        0.00     0.00
# 31        7.99     7.99
# 32        9.00     9.00
# 33        0.00     0.00
# 34        9.00     9.00
# 35        2.97     2.19
# 36        4.30     4.39
# 37        8.50     7.81
# 38        4.03     3.78
# 39        7.58     7.23
# 40        2.83     0.00
# 41        2.66     0.00
# 42        3.03     0.00
# 43        2.82     0.00
# 44        2.87     0.00

# %%
ve.head()
# Out:
#    Energy_load  Energy_distribution  Problem_Choice  Agent_choice  \
# 0            0                    0               0             1
# 1            0                    0               0             2
# 2            0                    0               0             3
# 3            0                    0               0             4
# 4            0                    0               1             0
#
#    Resolutions  Oversights  Flights  Quickies  Prob_unsolved  Prob_shifts  \
# 0         0.30        8.76     8.76      0.24          13.58        85.74
# 1         0.00        9.00     9.00      0.00          20.00        90.00
# 2         0.00        9.00     9.00      0.00          20.00        90.00
# 3         0.00        9.00     9.00      0.00          20.00        90.00
# 4         2.09        4.05     3.75      4.93           0.73        23.87
#
#    Prob_active  Prob_latency  Dm_active  Dm_shifts  Energy_spent  \
# 0       284.82           0.0     124.35      39.89       31.1796
# 1       310.00           0.0      29.00       0.00        9.8022
# 2       310.00           0.0     115.22      45.00       25.2354
# 3       310.00           0.0      55.92       3.60       18.4752
# 4        82.45          20.8     133.50      98.00       44.0550
#
#    Energy_excess  Choices_unsolved  Choices_active
# 0        17.4912               0.7           18.97
# 1         5.8884               1.0           20.00
# 2        12.3588               1.0           20.00
# 3        11.2152               1.0           20.00
# 4        22.8580               0.0           11.15
